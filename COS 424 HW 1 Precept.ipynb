# %% [markdown]
# # The Data
#
# ## Task: Classify songs by Genre
#
# 1. Blues
# 2. Classical
# 3. Country
# 4. Disco
# 5. Hiphop
# 6. Jazz
# 7. Metal
# 8. Pop
# 9. Reggae
# 10. Rock

# %%
#Play the two hiphop examples and rock.00013.p3.mp3 as an ambiguity example and pop.00017._8_3.mp3 as the worst thing in the world

# %% [markdown]
# ### Step 1 : Getting the data
#
# insert clickable link to github here

# %%
workingdir = '/Users/Ted/Documents/__G2_Spring/__COS_424/'
# !cd {workingdir} 
# !git clone https://github.com/grgliner/voxResources.git

# %% [markdown]
# # Loading Data directly into Python

# %%
import sys
import random
import scipy.io as spio
import numpy as np


fileN = '/Users/Ted/Documents/__G2_Spring/__COS_424/voxResources/data/country/country.00009.mat'
X = spio.loadmat(fileN)

# %% [markdown]
# # We also have a script that creates CSV files for each feature

# %%
# !python /Users/Ted/Documents/__G2_Spring/__COS_424/voxResources/tools/MAT2CSV.py {fileN}
# !ls '/Users/Ted/Documents/__G2_Spring/__COS_424/voxResources/data/country/'
# Out:
# Value not of recognized type
# country.00000.mat                        country.00023.mat                        country.00062.mat
# country.00001.mat                        country.00024.mat                        country.00063.mat
# country.00002.mat                        country.00025.mat                        country.00064.mat
# country.00003.mat                        country.00026.mat                        country.00065.mat
# country.00004.mat                        country.00027.mat                        country.00066.mat
# country.00005.mat                        country.00028.mat                        country.00067.mat
# country.00006.mat                        country.00029.mat                        country.00068.mat
# country.00007.mat                        country.00030.mat                        country.00069.mat
# country.00008.mat                        country.00031.mat                        country.00070.mat
# country.00009.mat                        country.00032.mat                        country.00071.mat
# country.00009_OPUS_centers.csv           country.00033.mat                        country.00072.mat
# country.00009_OPUS_chroma.csv            country.00034.mat                        country.00073.mat
# country.00009_OPUS_class.csv             country.00035.mat                        country.00074.mat
# country.00009_OPUS_eng.csv               country.00036.mat                        country.00075.mat
# country.00009_OPUS_env.csv               country.00037.mat                        country.00076.mat
# country.00009_OPUS_mfc.csv               country.00038.mat                        country.00077.mat
# country.00009_OPUS_other_brightness.csv  country.00039.mat                        country.00078.mat
# country.00009_OPUS_other_hcdf.csv        country.00040.mat                        country.00079.mat
# country.00009_OPUS_other_inharmonic.csv  country.00041.mat                        country.00080.mat
# country.00009_OPUS_other_key.csv         country.00042.mat                        country.00081.mat
# country.00009_OPUS_other_keystrength.csv country.00043.mat                        country.00082.mat
# country.00009_OPUS_other_onsets.csv      country.00044.mat                        country.00083.mat
# country.00009_OPUS_other_pitches.csv     country.00045.mat                        country.00084.mat
# country.00009_OPUS_other_roughness.csv   country.00046.mat                        country.00085.mat
# country.00009_OPUS_other_zerocross.csv   country.00047.mat                        country.00086.mat
# country.00009_OPUS_stat_flux.csv         country.00048.mat                        country.00087.mat
# country.00010.mat                        country.00049.mat                        country.00088.mat
# country.00011.mat                        country.00050.mat                        country.00089.mat
# country.00012.mat                        country.00051.mat                        country.00090.mat
# country.00013.mat                        country.00052.mat                        country.00091.mat
88412980923128, 100.09078460792611, 224.77432093214316, 166.35188147887754, 148.05976391507082, 101.12524736645456, 83.39897097069851, 96.08957263824527, 84.22226656878564, 79.76915071820109, 67.68133868582925, 77.58502104792603, 69.58286238561273, 63.40845067089587, 88.66813222188276, 95.67060058143053, 82.07354314785326, 82.59955330046266, 96.68605275262613, 77.67634811715807, 83.44940654196019, 115.03607015710831, 86.66994356270291, 75.18455448824427, 73.57397639888251, 102.12604732650102, 103.63840334058995, 196.0623676060888, 159.20681877663137, 127.92576369477149, 83.70083144230478, 95.9759607590112, 85.0402012090052, 85.54656464189532, 83.75558575813285, 67.18219295629635, 56.99214262814472, 64.09148050223773, 74.39909898782831, 104.1353836214684, 107.69363875877177, 56.08568514120696, 58.79133087732711, 57.31744365239646, 57.47948531693041, 55.86881130110443, 56.11627636364967, 53.698250162561166, 47.801519778108094, 50.85781328224614, 60.83466411900241, 78.34841118736105, 160.24727793551173, 188.0392803915815, 117.74641757876205, 94.56381420330908, 71.76462220756981, 65.38800637372428, 80.44566994194182, 58.150844778309285, 81.50516890519108, 71.96511635388003, 129.08104875691598, 101.86354922488225, 110.37874667617116, 69.19539188475778, 71.851522339495, 90.30617493243663, 91.2226872305643, 76.2295985586536, 72.95470703890616, 68.045057185704, 69.77280428039319, 72.04231343243005, 61.76815982221731, 79.84047932071056, 107.94852187090062, 182.23796618966466, 122.5499462044637, 122.68211262132077, 114.00541743355673, 91.48246274469854, 78.4844799556654, 94.85029691742801, 7 ...
#       dtype=[('flux', 'O')])]], dtype=object)

# %%
# Insert that table and talk about features
# We highly recomend looking at this in matlab - all computer clusters matlab and free from oit see the readme

# %% [markdown]
# # Ted's Talk
#
# these are matrices, you need vector vanilla approach doesn't work (we demo SVM results)

# %% [markdown]
# # Exemplars Code to do that insert unix commands here to show write OPTIONAL somewhere

# %% [markdown]
# # Main Point
#
# 3 types data you can use
#
# 1. Raw digital files
# 2. FV/Exemplar feature extraction
# 3. Extract your own features from the raw audio files (independent work)

# %% [markdown]
# # PT 2: Classifier Demos

# %%
# actual import mfcc from FV
import scipy.stats as stats
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import zero_one_loss
mfcc = X['OPUS']['mfc'][0][0]
N = mfcc.shape[1]
labels = np.array([i % 3 for i in range(0,N)])

maxLearners = 100
maxDepth = 5
TEidx = np.array(random.sample(range(0,N), N/10))
X_TE = mfcc[:,TEidx]
X_TR = mfcc[:,[i for i in range(0,N) if i not in TEidx]]
Y_TE = labels[TEidx]
Y_TR = labels[[i for i in range(0,N) if i not in TEidx]]
rf = RandomForestClassifier(n_estimators = maxLearners, max_depth = maxDepth, warm_start = False)
rf.fit(X_TR.T,Y_TR)
predictionsRF = rf.predict(X_TE.T)
errorRF = zero_one_loss(predictionsRF, Y_TE)
errorRF
# Out:
# 0.68333333333333335

# %%
k = 10
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_TR.T,Y_TR)
predictionsKNN = knn.predict(X_TE.T)
errorKNN = zero_one_loss(predictionsKNN, Y_TE)
errorKNN
# Out:
# 0.71666666666666667
